# %%
# !pip install pandas

# %%
import pandas as pd

# %%
df = pd.read_csv('C:\\Users\\Mirela\\PycharmProjects\\Womens Shoes\\Datafiniti_Womens_Shoes.csv')
df
# Out:
#                         id             dateAdded           dateUpdated asins  \
# 0     AVpfEf_hLJeJML431ueH  2015-05-04T12:13:08Z  2018-01-29T04:38:43Z   NaN
# 1     AVpi74XfLJeJML43qZAc  2017-01-27T01:23:39Z  2018-01-03T05:21:54Z   NaN
# 2     AVpi74XfLJeJML43qZAc  2017-01-27T01:23:39Z  2018-01-03T05:21:54Z   NaN
# 3     AVpjXyCc1cnluZ0-V-Gj  2017-01-27T01:25:56Z  2018-01-04T11:52:35Z   NaN
# 4     AVphGKLPilAPnD_x1Nrm  2017-01-27T01:25:56Z  2018-01-18T03:55:18Z   NaN
# ...                    ...                   ...                   ...   ...
# 9995  AWKcCm-RHh53nbDRIh1_  2018-04-06T17:33:30Z  2018-04-06T21:02:04Z   NaN
# 9996  AWKcEq-dHh53nbDRIiES  2018-04-06T17:33:29Z  2018-04-06T21:02:04Z   NaN
# 9997  AWKb5jmLYSSHbkXwyzBA  2018-04-06T16:46:35Z  2018-04-06T21:02:01Z   NaN
# 9998  AWKcEIInYSSHbkXwy0SA  2018-04-06T17:33:30Z  2018-04-06T21:01:53Z   NaN
# 9999  AWKb6PiKYSSHbkXwyzP-  2018-04-06T16:45:52Z  2018-04-06T21:01:50Z   NaN
#
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 34 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   10000 non-null  object
#  1   dateAdded            10000 non-null  object
#  2   dateUpdated          10000 non-null  object
#  3   asins                3 non-null      object
#  4   brand                10000 non-null  object
#  5   categories           10000 non-null  object
#  6   primaryCategories    10000 non-null  object
#  7   colors               2631 non-null   object
#  8   dimension            117 non-null    object
#  9   ean                  671 non-null    float64
#  10  imageURLs            10000 non-null  object
#  11  keys                 10000 non-null  object
#  12  manufacturer         527 non-null    object
#  13  manufacturerNumber   2482 non-null   object
#  14  name                 10000 non-null  object
# ...

# %% [markdown]
# The info() function is used to print a concise summary of a DataFrame. This method prints information about a DataFrame including the index dtype and column dtypes, non-null values and memory usage.

# %%
df.describe()
# Out:
#                 ean  prices.amountMax  prices.amountMin  prices.returnPolicy
# count  6.710000e+02      10000.000000      10000.000000                  0.0
# mean   7.714302e+11         69.223544         51.131209                  NaN
# std    1.847119e+11         19.487286         21.267446                  NaN
# min    3.397705e+10          5.870000          4.880000                  NaN
# 25%    7.276810e+11         59.990000         37.490000                  NaN
# 50%    8.701910e+11         64.990000         49.990000                  NaN
# 75%    8.860660e+11         79.990000         59.990000                  NaN
# max    8.898850e+11        359.950000        359.950000                  NaN

# %% [markdown]
# Pandas describe() is used to view some basic statistical details like percentile, mean, std etc. of a data frame or a series of numeric values.

# %%
df[['dateAdded','brand']]
# Out:
#                  dateAdded        brand
# 0     2015-05-04T12:13:08Z  Naturalizer
# 1     2017-01-27T01:23:39Z     MUK LUKS
# 2     2017-01-27T01:23:39Z     MUK LUKS
# 3     2017-01-27T01:25:56Z     MUK LUKS
# 4     2017-01-27T01:25:56Z     MUK LUKS
# ...                    ...          ...
# 9995  2018-04-06T17:33:30Z        Asics
# 9996  2018-04-06T17:33:29Z        Asics
# 9997  2018-04-06T16:46:35Z       Kaanas
# 9998  2018-04-06T17:33:30Z         Nike
# 9999  2018-04-06T16:45:52Z     OTZShoes
#
# [10000 rows x 2 columns]

# %% [markdown]
# With pandas DataFrame we can explore only two columns like dateAdded and band.

# %%
df[10:20]
# Out:
#                       id             dateAdded           dateUpdated asins  \
# 10  AVpfeWdJ1cnluZ0-lXYU  2017-01-07T20:51:22Z  2018-01-30T06:18:34Z   NaN
# 11  AVpf38PKLJeJML43FRwO  2016-11-04T02:01:08Z  2018-01-23T04:13:40Z   NaN
# 12  AVph9abqilAPnD_x_Nrp  2017-01-07T20:51:09Z  2018-01-04T11:52:59Z   NaN
# 13  AVph9abqilAPnD_x_Nrp  2017-01-07T20:51:09Z  2018-01-04T11:52:59Z   NaN
# 14  AVpgNGD6ilAPnD_xpAke  2016-11-04T02:28:40Z  2018-01-04T08:03:19Z   NaN
# 15  AVpgBzl41cnluZ0-vSQf  2017-01-17T19:08:54Z  2018-01-28T10:16:47Z   NaN
# 16  AVpgBzl41cnluZ0-vSQf  2017-01-17T19:08:54Z  2018-01-28T10:16:47Z   NaN
# 17  AVpgBzl41cnluZ0-vSQf  2017-01-17T19:08:54Z  2018-01-28T10:16:47Z   NaN
# 18  AVpivUm2ilAPnD_xHGfN  2017-01-07T20:51:08Z  2018-01-28T10:52:04Z   NaN
# 19  AVpivUm2ilAPnD_xHGfN  2017-01-07T20:51:08Z  2018-01-28T10:52:04Z   NaN
#
#        brand                                         categories  \
# 10  MUK LUKS  Clothing,Shoes,Women's Shoes,Women's Winter Bo...
# ...

# %%
df.groupby('brand')

# %%
# applying groupby() function to
# group the data on brand value.
df.groupby('brand').count()
# Out:
#                                  id  dateAdded  dateUpdated  asins  \
# brand
# 2 lips too                       19         19           19      0
# Adidas                           21         21           21      0
# Adidas Outdoor                    5          5            5      0
# Altra                            21         21           21      0
# Arc'teryx                         3          3            3      0
# ...                             ...        ...          ...    ...
# style charles by charles david  478        478          478      0
# sugar                             8          8            8      0
# under armour                     11         11           11      0
# unionbay                         55         55           55      0
# vans                             24         24           24      0
#
#                                 categories  primaryCategories  colors  \
# brand
# 2 lips too                              19                 19       0
# ...

# %%
df.groupby("brand")['categories'].count().sort_values().tail(10)
# Out:
# brand
# new balance                        255
# nike                               285
# croft barrow                       315
# dr. scholls                        337
# so                                 422
# style charles by charles david     478
# easy street                        556
# a2 by aerosoles                    670
# lifestride                        1457
# journee collection                2182
# Name: categories, dtype: int64

# %%
dfl=df.groupby("brand")['categories'].count().sort_values().tail(10).reset_index()
dfl
# Out:
#                             brand  categories
# 0                     new balance         255
# 1                            nike         285
# 2                    croft barrow         315
# 3                     dr. scholls         337
# 4                              so         422
# 5  style charles by charles david         478
# 6                     easy street         556
# 7                 a2 by aerosoles         670
# 8                      lifestride        1457
# 9              journee collection        2182

# %%
df['brand'] == 'new balance'
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9995    False
# 9996    False
# 9997    False
# 9998    False
# 9999    False
# Name: brand, Length: 10000, dtype: bool

# %%
df[df['brand'] == 'new balance']
# Out:
#                         id             dateAdded           dateUpdated asins  \
# 890   AV-ncqVLYSSHbkXwpaec  2017-11-10T19:33:32Z  2018-02-01T07:35:32Z   NaN
# 891   AV-ncqVLYSSHbkXwpaec  2017-11-10T19:33:32Z  2018-02-01T07:35:32Z   NaN
# 892   AV-ncqVLYSSHbkXwpaec  2017-11-10T19:33:32Z  2018-02-01T07:35:32Z   NaN
# 893   AV-ncqVLYSSHbkXwpaec  2017-11-10T19:33:32Z  2018-02-01T07:35:32Z   NaN
# 894   AV-ncqVLYSSHbkXwpaec  2017-11-10T19:33:32Z  2018-02-01T07:35:32Z   NaN
# ...                    ...                   ...                   ...   ...
# 9635  AV-KM5-MuC1rwyj_gSh_  2017-11-05T03:20:39Z  2018-01-18T07:01:00Z   NaN
# 9636  AV-KM5-MuC1rwyj_gSh_  2017-11-05T03:20:39Z  2018-01-18T07:01:00Z   NaN
# 9637  AV-KM5-MuC1rwyj_gSh_  2017-11-05T03:20:39Z  2018-01-18T07:01:00Z   NaN
# 9638  AV-KM5-MuC1rwyj_gSh_  2017-11-05T03:20:39Z  2018-01-18T07:01:00Z   NaN
# 9639  AV-KM5-MuC1rwyj_gSh_  2017-11-05T03:20:39Z  2018-01-18T07:01:00Z   NaN
#
# ...

# %% [markdown]
# Select only 'new balance' brand.

# %%
df[(df['prices.amountMin'] > 10) & (df['prices.amountMin'] < 20)]
# Out:
#                         id             dateAdded           dateUpdated asins  \
# 6     AVpjGKXyLJeJML43r8BH  2017-01-17T19:09:21Z  2018-10-15T15:50:13Z   NaN
# 7     AVpjGKXyLJeJML43r8BH  2017-01-17T19:09:21Z  2018-10-15T15:50:13Z   NaN
# 23    AVphX0ZbLJeJML43aHNG  2016-03-25T11:05:11Z  2018-01-04T08:02:27Z   NaN
# 24    AVpjDTKT1cnluZ0-TF44  2016-11-14T01:02:55Z  2018-01-04T08:03:26Z   NaN
# 135   AVpe9ZxsilAPnD_xRzci  2017-01-17T19:02:12Z  2018-01-28T09:01:21Z   NaN
# ...                    ...                   ...                   ...   ...
# 9635  AV-KM5-MuC1rwyj_gSh_  2017-11-05T03:20:39Z  2018-01-18T07:01:00Z   NaN
# 9636  AV-KM5-MuC1rwyj_gSh_  2017-11-05T03:20:39Z  2018-01-18T07:01:00Z   NaN
# 9637  AV-KM5-MuC1rwyj_gSh_  2017-11-05T03:20:39Z  2018-01-18T07:01:00Z   NaN
# 9638  AV-KM5-MuC1rwyj_gSh_  2017-11-05T03:20:39Z  2018-01-18T07:01:00Z   NaN
# 9639  AV-KM5-MuC1rwyj_gSh_  2017-11-05T03:20:39Z  2018-01-18T07:01:00Z   NaN
#
# ...

# %% [markdown]
# Select "prices.amountMin" to be in range 10 to 20.

# %%
dfl = df[df['brand'] == 'new balance']
dfl = dfl[['dateAdded', 'prices.amountMin']]
dfl
# Out:
#                  dateAdded  prices.amountMin
# 890   2017-11-10T19:33:32Z             48.74
# 891   2017-11-10T19:33:32Z             64.99
# 892   2017-11-10T19:33:32Z             64.99
# 893   2017-11-10T19:33:32Z             69.99
# 894   2017-11-10T19:33:32Z             59.99
# ...                    ...               ...
# 9635  2017-11-05T03:20:39Z             19.59
# 9636  2017-11-05T03:20:39Z             18.74
# 9637  2017-11-05T03:20:39Z             19.59
# 9638  2017-11-05T03:20:39Z             19.59
# 9639  2017-11-05T03:20:39Z             18.74
#
# [255 rows x 2 columns]

# %% [markdown]
# We can choose to select dateAdded and Prices.amountMin just for "new balance" brand

# %%
dfl.plot()
# Out:
# <AxesSubplot:>

# %%
dfl.head(10)
# Out:
#                 dateAdded  prices.amountMin
# 890  2017-11-10T19:33:32Z             48.74
# 891  2017-11-10T19:33:32Z             64.99
# 892  2017-11-10T19:33:32Z             64.99
# 893  2017-11-10T19:33:32Z             69.99
# 894  2017-11-10T19:33:32Z             59.99
# 895  2017-11-10T19:33:32Z             69.99
# 896  2017-11-10T19:33:32Z             69.99
# 897  2017-11-10T19:33:32Z             50.99
# 898  2017-11-10T19:33:32Z             48.99
# 899  2017-11-10T19:33:32Z             64.99

# %%
dfl.dropna().head(10)
# Out:
#                 dateAdded  prices.amountMin
# 890  2017-11-10T19:33:32Z             48.74
# 891  2017-11-10T19:33:32Z             64.99
# 892  2017-11-10T19:33:32Z             64.99
# 893  2017-11-10T19:33:32Z             69.99
# 894  2017-11-10T19:33:32Z             59.99
# 895  2017-11-10T19:33:32Z             69.99
# 896  2017-11-10T19:33:32Z             69.99
# 897  2017-11-10T19:33:32Z             50.99
# 898  2017-11-10T19:33:32Z             48.99
# 899  2017-11-10T19:33:32Z             64.99

# %%
dfl.interpolate().head(10)
# Out:
#                 dateAdded  prices.amountMin
# 890  2017-11-10T19:33:32Z             48.74
# 891  2017-11-10T19:33:32Z             64.99
# 892  2017-11-10T19:33:32Z             64.99
# 893  2017-11-10T19:33:32Z             69.99
# 894  2017-11-10T19:33:32Z             59.99
# 895  2017-11-10T19:33:32Z             69.99
# 896  2017-11-10T19:33:32Z             69.99
# 897  2017-11-10T19:33:32Z             50.99
# 898  2017-11-10T19:33:32Z             48.99
# 899  2017-11-10T19:33:32Z             64.99

# %%
dfl.interpolate().plot()
# Out:
# <AxesSubplot:>

# %%
dfl['prices.amountMin'].mean()
# Out:
# 56.87498039215672

# %%
dfl['prices.amountMin'].median()
# Out:
# 55.24

# %%
dfl.fillna(dfl['prices.amountMin'].mean()).plot()
# Out:
# <AxesSubplot:>

# %%
dfl.fillna(dfl['prices.amountMin'].mean()).head(10)
# Out:
#                 dateAdded  prices.amountMin
# 890  2017-11-10T19:33:32Z             48.74
# 891  2017-11-10T19:33:32Z             64.99
# 892  2017-11-10T19:33:32Z             64.99
# 893  2017-11-10T19:33:32Z             69.99
# 894  2017-11-10T19:33:32Z             59.99
# 895  2017-11-10T19:33:32Z             69.99
# 896  2017-11-10T19:33:32Z             69.99
# 897  2017-11-10T19:33:32Z             50.99
# 898  2017-11-10T19:33:32Z             48.99
# 899  2017-11-10T19:33:32Z             64.99

# %%
dfl = dfl.fillna(dfl['prices.amountMin'].mean())

# %%
dfl.iloc[0, 0]
# Out:
# '2017-11-10T19:33:32Z'

# %%
dfl.iloc[0, 0][:4]
# Out:
# '2017'

# %%
pd.to_datetime(dfl.iloc[0, 0])
# Out:
# Timestamp('2017-11-10 19:33:32+0000', tz='UTC')

# %%
pd.to_datetime(dfl.iloc[0, 0]).year
# Out:
# 2017

# %%
dfl['dateAdded'].apply(lambda x: pd.to_datetime(x).year)
# Out:
# 890     2017
# 891     2017
# 892     2017
# 893     2017
# 894     2017
#         ...
# 9635    2017
# 9636    2017
# 9637    2017
# 9638    2017
# 9639    2017
# Name: dateAdded, Length: 255, dtype: int64

# %%
dfl['year'] = dfl['dateAdded'].apply(lambda x: pd.to_datetime(x).year)
dfl
# Out:
#                  dateAdded  prices.amountMin  year
# 890   2017-11-10T19:33:32Z             48.74  2017
# 891   2017-11-10T19:33:32Z             64.99  2017
# 892   2017-11-10T19:33:32Z             64.99  2017
# 893   2017-11-10T19:33:32Z             69.99  2017
# 894   2017-11-10T19:33:32Z             59.99  2017
# ...                    ...               ...   ...
# 9635  2017-11-05T03:20:39Z             19.59  2017
# 9636  2017-11-05T03:20:39Z             18.74  2017
# 9637  2017-11-05T03:20:39Z             19.59  2017
# 9638  2017-11-05T03:20:39Z             19.59  2017
# 9639  2017-11-05T03:20:39Z             18.74  2017
#
# [255 rows x 3 columns]

# %%
dfl.groupby('year').mean()
# Out:
#       prices.amountMin
# year
# 2017          56.87498

# %%
dfl
# Out:
#                  dateAdded  prices.amountMin  year
# 890   2017-11-10T19:33:32Z             48.74  2017
# 891   2017-11-10T19:33:32Z             64.99  2017
# 892   2017-11-10T19:33:32Z             64.99  2017
# 893   2017-11-10T19:33:32Z             69.99  2017
# 894   2017-11-10T19:33:32Z             59.99  2017
# ...                    ...               ...   ...
# 9635  2017-11-05T03:20:39Z             19.59  2017
# 9636  2017-11-05T03:20:39Z             18.74  2017
# 9637  2017-11-05T03:20:39Z             19.59  2017
# 9638  2017-11-05T03:20:39Z             19.59  2017
# 9639  2017-11-05T03:20:39Z             18.74  2017
#
# [255 rows x 3 columns]

# %%
dfl['prices.amountMin'].rolling(12).mean().plot()
# Out:
# <AxesSubplot:>

# %%
import numpy as np

np.corrcoef(df['prices.amountMin'], df['prices.amountMax'])
# Out:
# array([[1.        , 0.69927962],
#        [0.69927962, 1.        ]])

# %%
dfp = df[['prices.amountMin', 'prices.amountMax']]
dfp.groupby('prices.amountMin')['prices.amountMax'].max().reset_index()
# Out:
#      prices.amountMin  prices.amountMax
# 0                4.88              5.87
# 1                4.96              5.87
# 2                7.49             24.99
# 3                7.88             12.44
# 4                7.90             14.00
# ..                ...               ...
# 275            170.00            170.00
# 276            178.00            178.00
# 277            179.95            179.95
# 278            289.95            289.95
# 279            359.95            359.95
#
# [280 rows x 2 columns]

# %%
dfp.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Conclusion
#
# I have successfully use type(), info(),discribe() to evaluate my dataframe.
#
# I also explored some rows and columns, and analysed the behaviour of new dataset I' ve obtained.
#
# Finally, I took a look at np.corrcoef() that returns the normalised covariance matrix between prices.amountMin and prices.amountMax.
#
# There is a positive correlation, and this correlation is 0.699, a strong positive correlation.let’s take a look at chart.
